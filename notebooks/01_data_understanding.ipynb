# %% [markdown]
# Imports

# %%
# !pip install pandas openpyxl numpy matplotlib missingno
# Out:
# ...
#   Using cached pandas-3.0.3-cp314-cp314-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached numpy-2.5.1-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# ...
#   Using cached matplotlib-3.11.0-cp314-cp314-win_amd64.whl.metadata (80 kB)
# ...
#   Using cached missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# ...
#   Using cached tzdata-2026.3-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# ...
#   Using cached contourpy-1.3.3-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.63.0-cp314-cp314-win_amd64.whl.metadata (121 kB)
# ...
#   Using cached kiwisolver-1.5.0-cp314-cp314-win_amd64.whl.metadata (5.2 kB)
# ...
#   Using cached pillow-12.3.0-cp314-cp314-win_amd64.whl.metadata (9.3 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...

# %%
import pandas as pd

# %% [markdown]
# loading data

# %%
sales = pd.read_excel("../data/raw/sales_details.xlsx")

loan1 = pd.read_excel("../data/raw/loan_list_1.xlsx")

loan2 = pd.read_csv("../data/raw/loan_list_2.csv")

# %%
sales.head()
# Out:
#          Date                           Company  \
# 0  11/07/2026  Antonio Phones & Accessories Hub
# 1  10/07/2026  Antonio Phones & Accessories Hub
# 2  10/07/2026  Antonio Phones & Accessories Hub
# 3  10/07/2026  Antonio Phones & Accessories Hub
# 4  10/07/2026  Antonio Phones & Accessories Hub
#
#                                 Agent  Customer_Name  Customer_Id  \
# 0   Kennedy Mulu | 0746125146 | KENYA  Benson chumba   38234909.0
# 1  WINFRED MUTUA | 0725527722 | KENYA     Ruth owino  329811043.0
# 2  WINFRED MUTUA | 0725527722 | KENYA     Diana aoko   34075285.0
# 3  WINFRED MUTUA | 0725527722 | KENYA    Idi onyango   11486487.0
# 4  WINFRED MUTUA | 0725527722 | KENYA   Milly omondi   31778127.0
#
#    Customer_Phone      Items       Serials     Bp       Sp  Margin
# 0     710305119.0  A200 4/64  3.550550e+14  12300  18187.0    5887
# 1     769671832.0  A200 4/64  3.550550e+14  13300  18187.0    4887
# 2     794009147.0  A200 4/64  3.550550e+14  13300  18187.0    4887
# ...

# %%
loan1.head()
# Out:
#   Agreement Number Issuance Date                         Dealer  \
# 0        AG9709415    2026-07-11  Antonio Phone Accessories Ltd
# 1        AG1569303    2026-07-11  Antonio Phone Accessories Ltd
# 2        AG0543337    2026-07-11  Antonio Phone Accessories Ltd
# 3        AG3919755    2026-07-11  Antonio Phone Accessories Ltd
# 4        AG9300916    2026-07-11  Antonio Phone Accessories Ltd
#
#                                          Shop            Agent  Loan Amount  \
# 0  Antonio Phone Accessories Ltd Lower Kabete    BETTY MUSYOKA        13724
# 1          Antonio Phone Accessories Murang'a      PAMELA AOKO        13724
# 2     Antonio phone accessories limited Nyeri  CAROLINE MUANGE        15476
# 3  Antonio Phone Accessories Ltd Lower Kabete  BENJAMIN MWENDA        13724
# 4  Antonio Phone Accessories Ltd Lower Kabete    BETTY MUSYOKA        13724
#
#    Phone Price  Brand Model Market Name             Imei  DPD  Debt  \
# ...

# %%
loan2.head()
# Out:
#   Agreement Number Issuance Date               Dealer  \
# 0        AG1873943   Jul 2, 2026  WHIXUS ZONA LIMITED
# 1        AG6142463   Jul 1, 2026  WHIXUS ZONA LIMITED
# 2        AG9124858   Jul 1, 2026  WHIXUS ZONA LIMITED
# 3        AG8855033   Jul 1, 2026  WHIXUS ZONA LIMITED
# 4        AG7199801   Jul 1, 2026  WHIXUS ZONA LIMITED
#
#                          Shop          Agent Loan Amount Phone Price  Brand  \
# 0  WHIXUS ZONE LIMITED _THIKA  FAITH WANGARI      12,051      15,650  Tecno
# 1  WHIXUS ZONE LIMITED _THIKA    PETER SAISI      12,051      15,650  Tecno
# 2  WHIXUS ZONE LIMITED _THIKA  FAITH WANGARI      12,051      15,650  Tecno
# 3  WHIXUS ZONE LIMITED _THIKA    JIMMY KYULE      12,051      15,650  Tecno
# 4  WHIXUS ZONE LIMITED _THIKA  KELVIN ONTITA      12,051      15,650  Tecno
#
#   Model Market Name             Imei  DPD Debt  Paid <4 in the first week  \
# 0   KN3      Pop 20  354493793126466    6  570                          1
# ...

# %% [markdown]
# Data Shape

# %%
print(sales.shape)

print(loan1.shape)

print(loan2.shape)
# Out:
# (215, 11)
# (1648, 15)
# (1115, 15)

# %% [markdown]
# Data Types

# %%
sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            215 non-null    str
#  1   Company         214 non-null    str
#  2   Agent           214 non-null    str
#  3   Customer_Name   214 non-null    str
#  4   Customer_Id     214 non-null    float64
#  5   Customer_Phone  214 non-null    float64
#  6   Items           214 non-null    str
#  7   Serials         214 non-null    float64
#  8   Bp              215 non-null    int64
#  9   Sp              215 non-null    float64
#  10  Margin          215 non-null    int64
# dtypes: float64(4), int64(2), str(5)
# memory usage: 18.6 KB

# %%
loan1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1648 entries, 0 to 1647
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Agreement Number             1648 non-null   str
#  1   Issuance Date                1648 non-null   datetime64[us]
#  2   Dealer                       1648 non-null   str
#  3   Shop                         1648 non-null   str
#  4   Agent                        1648 non-null   str
#  5   Loan Amount                  1648 non-null   int64
#  6   Phone Price                  1648 non-null   int64
#  7   Brand                        1648 non-null   str
#  8   Model                        1648 non-null   str
#  9   Market Name                  1648 non-null   str
#  10  Imei                         1648 non-null   int64
#  11  DPD                          1648 non-null   int64
#  12  Debt                         523 non-null    float64
# ...

# %%
loan2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Agreement Number             1115 non-null   str
#  1   Issuance Date                1115 non-null   str
#  2   Dealer                       1115 non-null   str
#  3   Shop                         1115 non-null   str
#  4   Agent                        1115 non-null   str
#  5   Loan Amount                  1115 non-null   str
#  6   Phone Price                  1115 non-null   str
#  7   Brand                        1115 non-null   str
#  8   Model                        1115 non-null   str
#  9   Market Name                  1115 non-null   str
#  10  Imei                         1115 non-null   int64
#  11  DPD                          1115 non-null   int64
#  12  Debt                         488 non-null    str
# ...

# %% [markdown]
# Missing Values

# %%
sales.isna().sum().sort_values(ascending=False)
# Out:
# Company           1
# Agent             1
# Customer_Name     1
# Serials           1
# Customer_Id       1
# Customer_Phone    1
# Items             1
# Date              0
# Bp                0
# Sp                0
# Margin            0
# dtype: int64

# %%
loan1.isna().sum().sort_values(ascending=False)
# Out:
# Paid <15 in the first month    1648
# Debt                           1125
# Paid <4 in the first week        93
# Shop                              0
# Agreement Number                  0
# Issuance Date                     0
# Dealer                            0
# Phone Price                       0
# Loan Amount                       0
# Agent                             0
# Brand                             0
# Imei                              0
# Market Name                       0
# Model                             0
# DPD                               0
# dtype: int64

# %%
loan2.isna().sum().sort_values(ascending=False)
# Out:
# Debt                           627
# Paid <15 in the first month    323
# Agreement Number                 0
# Shop                             0
# Agent                            0
# Issuance Date                    0
# Dealer                           0
# Phone Price                      0
# Loan Amount                      0
# Brand                            0
# Model                            0
# Imei                             0
# Market Name                      0
# DPD                              0
# Paid <4 in the first week        0
# dtype: int64

# %% [markdown]
# Duplicates

# %%
sales.duplicated().sum()
# Out:
# np.int64(0)

# %%
loan1.duplicated().sum()
# Out:
# np.int64(0)

# %%
loan2.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Unique Values

# %%
sales["Company"].value_counts()
# Out:
# Company
# Antonio Phones & Accessories Hub    214
# Name: count, dtype: int64

# %%
loan1["Dealer"].value_counts()
# Out:
# Dealer
# Antonio Phone Accessories Ltd    1648
# Name: count, dtype: int64

# %%
loan2["Dealer"].value_counts()
# Out:
# Dealer
# WHIXUS ZONA LIMITED    1115
# Name: count, dtype: int64

# %% [markdown]
# checking serial numbers

# %%
sales["Serials"].head()
# Out:
# 0    3.550550e+14
# 1    3.550550e+14
# 2    3.550550e+14
# 3    3.550550e+14
# 4    3.550550e+14
# Name: Serials, dtype: float64

# %% [markdown]
# profile report

# %%
sales.describe(include="all")
# Out:
#               Date                           Company  \
# count          215                               214
# unique           6                                 1
# top     07/07/2026  Antonio Phones & Accessories Hub
# freq            69                               214
# mean           NaN                               NaN
# std            NaN                               NaN
# min            NaN                               NaN
# 25%            NaN                               NaN
# 50%            NaN                               NaN
# 75%            NaN                               NaN
# max            NaN                               NaN
#
#                                       Agent Customer_Name   Customer_Id  \
# count                                   214           214  2.140000e+02
# unique                                   15           212           NaN
# top     kIVUVA CHARLES | 0798592138 | KENYA   Seline auma           NaN
# ...

# %%
loan1.describe(include="all")
# Out:
#        Agreement Number               Issuance Date  \
# count              1648                        1648
# unique             1648                         NaN
# top           AG9709415                         NaN
# freq                  1                         NaN
# mean                NaN  2026-06-20 18:01:44.854369
# min                 NaN         2026-06-11 00:00:00
# 25%                 NaN         2026-06-15 00:00:00
# 50%                 NaN         2026-06-19 00:00:00
# 75%                 NaN         2026-06-27 00:00:00
# max                 NaN         2026-07-11 00:00:00
# std                 NaN                         NaN
#
#                                Dealer                                 Shop  \
# count                            1648                                 1648
# unique                              1                                   12
# top     Antonio Phone Accessories Ltd  Antonio Phone Accessories Ltd Thika
# ...

# %%
loan2.describe(include="all")
# Out:
#        Agreement Number Issuance Date               Dealer  \
# count              1115          1115                 1115
# unique             1115            65                    1
# top           AG1873943  May 29, 2026  WHIXUS ZONA LIMITED
# freq                  1            35                 1115
# mean                NaN           NaN                  NaN
# std                 NaN           NaN                  NaN
# min                 NaN           NaN                  NaN
# 25%                 NaN           NaN                  NaN
# 50%                 NaN           NaN                  NaN
# 75%                 NaN           NaN                  NaN
# max                 NaN           NaN                  NaN
#
#                               Shop        Agent Loan Amount Phone Price Brand  \
# count                         1115         1115        1115        1115  1115
# unique                           2           11          15          15     3
# ...
